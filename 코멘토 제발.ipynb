# %%
import numpy as np
a = np.array([[1000,889],[1000,879],[1000,887],[1000,894],[1000,887],[1000,902],[1000,888],[1000,902],[1000,897],[1000,889],[1000,899],[1000,897],[1000,876],[1000,870],[1000,891],[1000,893],[1000,907],[1000,875],[1000,887],[1000,898],[1000,892],[1000,910],[1000,895],[1000,910],[1000,914],[1000,914],[1000,905],[1000,896],[1000,903],[1000,901],[1000,886],[1000,908],[1000,900],[1000,913],[1000,905],[1000,894],[1000,872],[1000,892],[1000,897],[1000,880],[1000,901],[1000,897],[1000,911],[1000,876],[1000,912],[1000,887],[1000,902],[1000,918],[1000,909],[1000,908],[1000,894],[1000,898],[1000,875],[1000,879],[1000,882],[1000,900],[1000,917],[1000,904],[1000,910],[1000,888],[1000,885],[1000,902],[1000,880],[1000,883],[1000,880],[1000,882],[1000,892],[1000,909],[1000,900],[1000,888],[1000,888],
             [1000,869],[1000,902],[1000,877],[1000,887],[1000,910],[1000,904],[1000,919],[1000,892],[1000,910],[1000,891],[1000,899],[1000,899],[1000,894],[1000,904],[1000,910],[1000,893],[1000,901],[1000,898],[1000,893],[1000,912],[1000,901],[1000,890],[1000,883],[1000,888],[1000,872],[1000,888],[1000,895],[1000,891],[1000,884],[1000,878],[1000,905],[1000,888],[1000,910],[1000,909],[1000,923],[1000,918]])
print(a)
# Out:
# [[1000  889]
#  [1000  879]
#  [1000  887]
#  [1000  894]
#  [1000  887]
#  [1000  902]
#  [1000  888]
#  [1000  902]
#  [1000  897]
#  [1000  889]
#  [1000  899]
#  [1000  897]
#  [1000  876]
#  [1000  870]
#  [1000  891]
#  [1000  893]
#  [1000  907]
#  [1000  875]
#  [1000  887]
#  [1000  898]
#  [1000  892]
#  [1000  910]
#  [1000  895]
#  [1000  910]
#  [1000  914]
#  [1000  914]
#  [1000  905]
#  [1000  896]
#  [1000  903]
#  [1000  901]
#  [1000  886]
#  [1000  908]
#  [1000  900]
#  [1000  913]
#  [1000  905]
#  [1000  894]
#  [1000  872]
#  [1000  892]
#  [1000  897]
#  [1000  880]
#  [1000  901]
#  [1000  897]
#  [1000  911]
#  [1000  876]
#  [1000  912]
#  [1000  887]
#  [1000  902]
#  [1000  918]
#  [1000  909]
#  [1000  908]
#  [1000  894]
#  [1000  898]
#  [1000  875]
#  [1000  879]
#  [1000  882]
#  [1000  900]
#  [1000  917]
#  [1000  904]
#  [1000  910]
#  [1000  888]
#  [1000  885]
#  [1000  902]
#  [1000  880]
#  [1000  883]
#  [1000  880]
#  [1000  882]
# ...

# %%
print(type(a))
# Out:
# <class 'numpy.ndarray'>

# %%
from pyspc import *
import numpy
import matplotlib.pyplot as plt

v = spc(a) + p() + rules()
print(v)
# Out:
# <pyspc: (106762278154)>

# %%
g = spc(a) + c() + rules()
print(g)
# Out:
# <pyspc: (106767813557)>

# %%
d = spc(circuits) + c() + rules()
print(d)
# Out:
# <pyspc: (106762296595)>

# %%
e = spc(circuits) + p() + rules()
print(e)
# Out:
# <pyspc: (106767913834)>
